# %% [markdown]
# # Linked Lists in Python – Exercises

# %% [markdown]
# ## Part 1 — Basics (Node and LinkedList fundamentals)
#
# 1. **Create a Node class** with `data` and `next` attributes.
# 2. **Create a LinkedList class** with a `head` attribute (initially `None`).
# 3. Implement a method `print_list()` that traverses and prints the list.
# 4. Implement a method `length()` that returns the number of nodes.
# 5. Implement `search(value)` that returns `True` if the value exists in the list.

# %% [markdown]
# 1. **Create a Node class** with `data` and `next` attributes.

# %%
class Node():
    def __init__(self, data):
        self.data = data
        self.next = None

# %% [markdown]
# 2. **Create a LinkedList class** with a `head` attribute (initially `None`).

# %%
class LinkedList():
    def __init__(self):
        self.head = None

# %% [markdown]
# 3. Implement a method `print_list()` that traverses and prints the list.

# %%
class LinkedList():
    def __init__(self):
        self.head = None
        
    def print_list(self):
        current = self.head
        while current:
            print(current.data, end=" -> ")
            current = current.next
        print("None")

# %% [markdown]
# 4. Implement a method `length()` that returns the number of nodes.

# %%
class LinkedList():
    def __init__(self):
        self.head = None
        
    def length(self):
        current = self.head
        len = 0
        while current:
            current = current.next
            len += 1
        return len
    
node0 = Node(10)
node1 = Node(11)
node2 = Node(12)

node0.next = node1
node1.next = node2

linkedlist = LinkedList()
linkedlist.head = node0

print(linkedlist.length())
# Out:
# 3

# %% [markdown]
# 5. Implement `search(value)` that returns `True` if the value exists in the list.

# %%
class LinkedList():
    def __init__(self):
        self.head: Node = None
        
    def search(self, value):
        current = self.head
        
        if not current:
            return False
        
        while current:
            if current.data == value:
                return True
            current = current.next
        return False
    
node0 = Node(10)
node1 = Node(11)
node2 = Node(12)

node0.next = node1
node1.next = node2

linkedlist = LinkedList()
linkedlist.head = node0

print(linkedlist.search(10))
# Out:
# True

# %% [markdown]
# ## Part 2 — Insertions
#
# 6. Implement `insert_at_beginning(data)`.
# 7. Implement `insert_at_end(data)`.
# 8. Implement `insert_at_index(index, data)` (0-based index).
#
#    * Raise an error if index is out of bounds.
# 9. Write a program that inserts the values `[5, 10, 15]` at the end of the list and prints it.

# %% [markdown]
# ## Part 3 — Deletions
#
# 10. Implement `delete_by_value(value)`.
# 11. Implement `delete_by_index(index)` (0-based index).
# 12. Modify `delete_by_value(value)` so it deletes **only the first occurrence** of the value.
# 13. Extend it to `delete_all(value)` that removes all nodes with a given value.

# %% [markdown]
# ## Part 4 — Intermediate Exercises
#
# 14. Implement `get_nth(index)` that returns the node’s data at position `index`.
# 15. Implement `get_nth_from_end(n)` (e.g., `n=1` gives last element).
# 16. Implement `reverse()` that reverses the linked list in-place.
# 17. Implement `is_empty()` that checks if the list is empty.
# 18. Write a program that:
#
# * Creates a list with `[1,2,3,4,5]`
# * Deletes the head, the tail, and a middle element
# * Prints the result after each operation.

# %% [markdown]
# ## Part 5 — Doubly Linked List
#
# 19. Implement a **DoublyLinkedList** class with `append(data)` and `prepend(data)`.
# 20. Add `print_forward()` and `print_backward()`.
# 21. Implement `delete_by_value(value)` for the doubly linked list.
# 22. Write a program that builds `[0,1,2,3,4]`, deletes `2`, and prints both forward and backward.

# %% [markdown]
# ## Part 6 — Circular Linked List
#
# 23. Implement a **CircularLinkedList** class with `append(data)`.
# 24. Add a method `print_list()` that loops until it reaches the head again.
# 25. Implement `delete_by_value(value)` in the circular linked list.
# 26. Write a program that creates a circular list `[1,2,3,4]` and demonstrates traversal.

# %% [markdown]
# ## Part 7 — Advanced Challenges
#
# 27. Implement `merge_sorted(list1, list2)` that merges two **sorted** singly linked lists into one sorted list.
# 28. Implement `find_middle()` that returns the middle node’s data (use slow/fast pointer technique).
# 29. Implement `has_cycle()` (Floyd’s cycle detection algorithm).
# 30. Implement `remove_duplicates()` for an **unsorted linked list**.
# 31. Write a method `rotate(k)` that rotates the linked list to the right by `k` positions.
#
# * Example: `[10,20,30,40,50]` rotated by 2 → `[40,50,10,20,30]`.
#
# 32. Implement `partition(x)` that rearranges nodes so that all nodes `< x` come before nodes `≥ x`.

# %% [markdown]
# ## Part 8 — Bonus (for mastery)
#
# 33. Implement a function that converts a **Python list → Linked List**.
# 34. Implement a function that converts a **Linked List → Python list**.
# 35. Implement `palindrome_check()` that checks if the linked list is a palindrome.
# 36. Implement `sum_lists(l1, l2)` where two linked lists represent integers (e.g., `617` = `7->1->6`) and return the sum as a linked list.
